# %% [markdown]
# <a href="https://colab.research.google.com/github/drewscottt/UArizona-RMP/blob/main/UArizona_RMP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is my final project for ISTA322. In it, I extract information about professors at the University of Arizona from two sources (a salary sheet and RateMyProfessor API). Then, I transform the data to filter interesting information about the data, use libraries to infer demographic information about the professors, and aggregate data to create datasets for each department and course at the UofA. Then, I load all of this information into a database. I have example queries for each of the tables loaded into the DB, showing what sorts of questions can be asked about the data.
#
# [My original plan](https://docs.google.com/document/d/1RWUIrtQrgzBvJRRMYXLDIr0429hGngkLyFeovoPUHlE/edit?usp=sharing)

# %% [markdown]
# ##Installations
# This will automatically restart the runtime environment (otherwise errors will be caused later on in the project), so a crashed message will show, but that's okay.

# %%
# !pip install -U -q jsonmerge
# !pip install gender-guesser
# !pip install ethnicolr
# !pip3 install mysql-connector-python

# need to restart runtime for some reason
import os
os.kill(os.getpid(), 9)
# Out:
#   Building wheel for jsonmerge (setup.py) ... done
# Collecting gender-guesser
#   Downloading gender_guesser-0.4.0-py2.py3-none-any.whl (379 kB)
#      |████████████████████████████████| 379 kB 21.0 MB/s
# Installing collected packages: gender-guesser
# Successfully installed gender-guesser-0.4.0
# Collecting ethnicolr
#   Downloading ethnicolr-0.8.1-py2.py3-none-any.whl (36.1 MB)
#      |████████████████████████████████| 36.1 MB 170 kB/s
# Collecting tensorflow==2.5.2
#   Downloading tensorflow-2.5.2-cp37-cp37m-manylinux2010_x86_64.whl (454.4 MB)
#      |████████████████████████████████| 454.4 MB 23 kB/s
# Collecting pandas>=1.3.0
#   Downloading pandas-1.3.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 43.8 MB/s
# Requirement already satisfied: numpy~=1.19.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.2->ethnicolr) (1.19.5)
# Collecting typing-extensions~=3.7.4
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.2->ethnicolr) (1.6.3)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.2->ethnicolr) (3.17.3)
# Collecting tensorflow-estimator<2.6.0,>=2.5.0
#   Downloading tensorflow_estimator-2.5.0-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 30.3 MB/s
# Collecting wrapt~=1.12.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Collecting flatbuffers~=1.12.0
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.2->ethnicolr) (0.2.0)
# Collecting grpcio~=1.34.0
#   Downloading grpcio-1.34.1-cp37-cp37m-manylinux2014_x86_64.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 41.6 MB/s
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.2->ethnicolr) (1.15.0)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.2->ethnicolr) (1.1.0)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.2->ethnicolr) (0.37.0)
# Requirement already satisfied: tensorboard~=2.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.2->ethnicolr) (2.7.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.2->ethnicolr) (1.1.2)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.2->ethnicolr) (0.12.0)
# Requirement already satisfied: gast==0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.2->ethnicolr) (0.4.0)
# Requirement already satisfied: h5py~=3.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.2->ethnicolr) (3.1.0)
# Collecting keras-nightly~=2.5.0.dev
#   Downloading keras_nightly-2.5.0.dev2021032900-py2.py3-none-any.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 61.2 MB/s
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.2->ethnicolr) (3.3.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py~=3.1.0->tensorflow==2.5.2->ethnicolr) (1.5.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.3.0->ethnicolr) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.3.0->ethnicolr) (2.8.2)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow==2.5.2->ethnicolr) (57.4.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow==2.5.2->ethnicolr) (2.23.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow==2.5.2->ethnicolr) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow==2.5.2->ethnicolr) (1.35.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow==2.5.2->ethnicolr) (3.3.6)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow==2.5.2->ethnicolr) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow==2.5.2->ethnicolr) (1.8.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow==2.5.2->ethnicolr) (0.4.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.2->ethnicolr) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.2->ethnicolr) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.2->ethnicolr) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow==2.5.2->ethnicolr) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.5->tensorflow==2.5.2->ethnicolr) (4.8.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.5->tensorflow==2.5.2->ethnicolr) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.2->ethnicolr) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.2->ethnicolr) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.2->ethnicolr) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.2->ethnicolr) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.2->ethnicolr) (2021.10.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow==2.5.2->ethnicolr) (3.1.1)
# Building wheels for collected packages: wrapt
#   Building wheel for wrapt (setup.py) ... done
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp37-cp37m-linux_x86_64.whl size=68716 sha256=06ed9c505f2fbcca94da910f1d9e46f04b514e804db4df0f997cc44cfa94e22b
#   Stored in directory: /root/.cache/pip/wheels/62/76/4c/aa25851149f3f6d9785f6c869387ad82b3fd37582fa8147ac6
# Successfully built wrapt
# Installing collected packages: typing-extensions, grpcio, wrapt, tensorflow-estimator, keras-nightly, flatbuffers, tensorflow, pandas, ethnicolr
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.10.0.2
#     Uninstalling typing-extensions-3.10.0.2:
#       Successfully uninstalled typing-extensions-3.10.0.2
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.42.0
#     Uninstalling grpcio-1.42.0:
#       Successfully uninstalled grpcio-1.42.0
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.13.3
#     Uninstalling wrapt-1.13.3:
#       Successfully uninstalled wrapt-1.13.3
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.7.0
#     Uninstalling tensorflow-estimator-2.7.0:
#       Successfully uninstalled tensorflow-estimator-2.7.0
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 2.0
#     Uninstalling flatbuffers-2.0:
#       Successfully uninstalled flatbuffers-2.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.7.0
#     Uninstalling tensorflow-2.7.0:
#       Successfully uninstalled tensorflow-2.7.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.1.5
#     Uninstalling pandas-1.1.5:
#       Successfully uninstalled pandas-1.1.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas~=1.1.0; python_version >= "3.0", but you have pandas 1.3.5 which is incompatible.
# Successfully installed ethnicolr-0.8.1 flatbuffers-1.12 grpcio-1.34.1 keras-nightly-2.5.0.dev2021032900 pandas-1.3.5 tensorflow-2.5.2 tensorflow-estimator-2.5.0 typing-extensions-3.7.4.3 wrapt-1.12.1
# Requirement already satisfied: mysql-connector-python in /usr/local/lib/python3.7/dist-packages (8.0.27)
# Requirement already satisfied: protobuf>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from mysql-connector-python) (3.17.3)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.0.0->mysql-connector-python) (1.15.0)

# %% [markdown]
# ##Import modules

# %%
# used to read from Google Drive 
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# used to request from APIs and manage their json responses
import urllib.request
import json
from jsonmerge import merge, Merger

import pandas as pd
import numpy as np
import math

# used to infer demographic information about professors
import gender_guesser.detector as gender
from ethnicolr import census_ln
# Out:
# /usr/local/lib/python3.7/dist-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %% [markdown]
# ##Google Drive Authentication

# %%
# Authenticate access to Google Drive
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %% [markdown]
# #Extract
# Data sources:
# * [UArizona Employee Salaries (2019-20)](https://docs.google.com/spreadsheets/d/e/2PACX-1vTaAWak0pN6Jnulm95eTM7kIubvNNMPgYh3d6sCHN5W1tekpIktoMBoDKJeZhmAyI7ZzH1BAytEp_bV/pubhtml?lsrp=1) (Google Sheet), [My Version](https://drive.google.com/file/d/1NrJKzMENRlp8Y-G4ATDq733imXs61b70/view?usp=sharing) (CSV)
# * [RateMyProfessor UArizona Professors](https://www.ratemyprofessors.com/filter/professor/?&page=1&filter=teacherlastname_sort_s+asc&query=*%3A*&queryoption=TEACHER&queryBy=schoolId&sid=1402) (JSON), [All pages merged to one](https://drive.google.com/file/d/1f8A51h7dCGqdNe4sZKekCi4aZOht23-n/view?usp=sharing) (JSON)
# * [RateMyProfessor Reviews](https://www.ratemyprofessors.com/paginate/professors/ratings?tid=180399) (JSON) [All merged to one](https://drive.google.com/file/d/13QDkDkIZDkmzEon0eZYJ3QLVWlrDPtoQ/view?usp=sharing) (JSON)
#
# The goals of this section are:
#
# 1. Extract the information from UArizona Salaries Sheet and load it into a csv file on my Google Drive, then load the Google Drive csv into a DataFrame
# 2. Extract the Professors from the RMP Professors API and load it into a json file on my Google Drive, then load it into a DataFrame
# 3. Find the Professors who exist in both datasets, and join these sets together into one DataFrame
# 4. Extract the reviews for each Professor in the merged DF from the RMP API, and load it into a json file on my Google Drive, then load it into a DataFrame
#
# End Result:
# * Have 2 DataFrames: merged_df and reviews_df

# %%
# Extract Employees from UArizona Salaries Sheet

# get the salary file from Google Drive, name it salaries.csv
salaries_url = 'https://drive.google.com/file/d/1NrJKzMENRlp8Y-G4ATDq733imXs61b70/view?usp=sharing'
salaries_csv_drive = drive.CreateFile({'id':'1NrJKzMENRlp8Y-G4ATDq733imXs61b70'})
salaries_csv_drive.GetContentFile('salaries.csv')

# read salaries.csv into a df
salaries_df = pd.read_csv('salaries.csv')

# we need to transform the name column to FirstName and LastName so we can use it to get professor reviews from RMP

# split the Name column into FirstName and LastName
salaries_df[['LastName', 'FirstName']] = salaries_df['Name'].str.split(',', expand=True)

# remove middle names/initials from FirstName column
salaries_df['FirstName'] = salaries_df['FirstName'].str.split(expand=True)[0]

salaries_df
# Out:
#                                  Name  ...  FirstName
# 0                       Miller,Sean E  ...       Sean
# 1                        Nakaji,Peter  ...      Peter
# 2                        Sumlin,Kevin  ...      Kevin
# 3                      Robbins,Robert  ...     Robert
# 4                        Dake,Michael  ...    Michael
# ...                               ...  ...        ...
# 12885              Mast,Ian MacArthur  ...        Ian
# 12886  Andreacola,Darla Rachelle Kuhn  ...      Darla
# 12887                  Bee,Victoria G  ...   Victoria
# 12888                     Nett,Mary A  ...       Mary
# 12889     Reichsfeld,Alexander Justin  ...  Alexander
#
# [12890 rows x 11 columns]

# %%
# Extract the Professors from the RMP Professors API
# *** IMPORTANT: This cell shouldn't be run again because the results of this cell
#                 have been cached a Google Drive file. Rerunning will result in 
#                 unnecessary network traffic.
'''
rmp_professor_base = 'https://www.ratemyprofessors.com/filter/professor/?'
rmp_parameters = '&filter=teacherlastname_sort_s+asc&query=*%3A*&queryoption=TEACHER&queryBy=schoolId&sid=1402'

rmp_url = rmp_professor_base + 'page=1' + rmp_parameters
# get the total number of UArizona Professors on RMP
with urllib.request.urlopen(rmp_url) as url:
    data = json.loads(url.read().decode())
    count_profs = data['searchResultsTotal']

# there are 20 professors listed on each page
pages_needed = math.ceil(count_profs / 20)

# get all of the professors from each page, save them in rmp_professors list
rmp_professors = []
for page_num in range(1, pages_needed + 1):
  rmp_url = rmp_professor_base + f'page={page_num}' + rmp_parameters
  with urllib.request.urlopen(rmp_url) as url:
    data = json.loads(url.read().decode())
    rmp_professors.append(data)

# now, merge each of these json pages into one json file object using the jsonmerge module

# this schema specifies to append each professor list to the already merged file
# instead of overwriting the previous one (which is the default)
schema = {
          "properties": {
              "professors": {
                  "mergeStrategy": "append"
              }             
          }
         }

# merge all of the json objects together, via a chaining method
merger = Merger(schema)
merged_professors = merger.merge(rmp_professors[0], rmp_professors[1])
for i in range(2, len(rmp_professors)):
  merged_professors = merger.merge(merged_professors, rmp_professors[i])

# dump the merged_professors json object into rmp_professors.json file
with open("rmp_professors.json", "w") as rmp_prof_json:
     json.dump(merged_professors, rmp_prof_json)

# I manually saved this dumped file to my Google Drive for future use
'''
# Out:
# '\nrmp_professor_base = \'https://www.ratemyprofessors.com/filter/professor/?\'\nrmp_parameters = \'&filter=teacherlastname_sort_s+asc&query=*%3A*&queryoption=TEACHER&queryBy=schoolId&sid=1402\'\n\nrmp_url = rmp_professor_base + \'page=1\' + rmp_parameters\n# get the total number of UArizona Professors on RMP\nwith urllib.request.urlopen(rmp_url) as url:\n    data = json.loads(url.read().decode())\n    count_profs = data[\'searchResultsTotal\']\n\n# there are 20 professors listed on each page\npages_needed = math.ceil(count_profs / 20)\n\n# get all of the professors from each page, save them in rmp_professors list\nrmp_professors = []\nfor page_num in range(1, pages_needed + 1):\n  rmp_url = rmp_professor_base + f\'page={page_num}\' + rmp_parameters\n  with urllib.request.urlopen(rmp_url) as url:\n    data = json.loads(url.read().decode())\n    rmp_professors.append(data)\n\n# now, merge each of these json pages into one json file object using the jsonmerge module\n\n# this schema specifies to append each professor list to the already merged file\n# instead of overwriting the previous one (which is the default)\nschema = {\n          "properties": {\n              "professors": {\n                  "mergeStrategy": "append"\n              }             \n          }\n         }\n\n# merge all of the json objects together, via a chaining method\nmerger = Merger(schema)\nmerged_professors = merger.merge(rmp_professors[0], rmp_professors[1])\nfor i in range(2, len(rmp_professors)):\n  merged_professors = merger.merge(merged_professors, rmp_professors[i])\n\n# dump the merged_professors json object into rmp_professors.json file\nwith open("rmp_professors.json", "w") as rmp_prof_json:\n     json.dump(merged_professors, rmp_prof_json)\n\n# I manually saved this dumped file to my Google Drive for future use\n'

# %%
# Continue extracting the RMP Professors, now that we have the json files all merged into one

# load the json file from Google Drive
professors_url = 'https://drive.google.com/file/d/1f8A51h7dCGqdNe4sZKekCi4aZOht23-n/view?usp=sharing'
professors_json_drive = drive.CreateFile({'id':'1f8A51h7dCGqdNe4sZKekCi4aZOht23-n'})
professors_json_drive.GetContentFile('rmp_professors.json')
with open('rmp_professors.json', 'r') as rmp_json:
  rmp_professors = json.load(rmp_json)['professors']

# convert json to df
rmp_professors_df = pd.json_normalize(rmp_professors)

# rename first and last name columns so we can easily merge it with salaries_df

rmp_professors_df.rename(columns={'tFname' : 'FirstName', 'tLname' : 'LastName'}, inplace=True)

rmp_professors_df
# Out:
#              tDept  tSid  ... categoryType overall_rating
# 0              Law  1402  ...    PROFESSOR            3.2
# 1       Literature  1402  ...    PROFESSOR            2.1
# 2     Architecture  1402  ...    PROFESSOR            2.0
# 3      Engineering  1402  ...    PROFESSOR            1.3
# 4      Mathematics  1402  ...    PROFESSOR            5.0
# ...            ...   ...  ...          ...            ...
# 5283  Architecture  1402  ...    PROFESSOR            N/A
# 5284      Business  1402  ...    PROFESSOR            3.3
# 5285       English  1402  ...    PROFESSOR            4.2
# 5286       English  1402  ...    PROFESSOR            4.3
# 5287   Agriculture  1402  ...    PROFESSOR            4.2
#
# [5288 rows x 12 columns]

# %%
# Merge rmp_professors_df with salaries_df on FirstName and LastName
merged_df = pd.merge(rmp_professors_df, salaries_df, how='inner', on=['FirstName', 'LastName'])

merged_df
# Out:
#                      tDept  ...                   Department
# 0               Literature  ...             Africana Studies
# 1                  English  ...                      English
# 2                Sociology  ...                    Sociology
# 3                Economics  ...                    Economics
# 4     Spanish & Portuguese  ...       Spanish and Portuguese
# ...                    ...  ...                          ...
# 1683           Engineering  ...  Aerospace & Mechanical Engr
# 1684       Natural Science  ...  Hydrology & Atmospheric Sci
# 1685          Architecture  ...      Planning Degree Program
# 1686              Business  ...    Agric & Resource Econ-Ins
# 1687               English  ...                      English
#
# [1688 rows x 21 columns]

# %%
# Now that we have the Professors who were found in both datasets, we can extract our last data set: reviews
# *** IMPORTANT: This cell shouldn't be run again because the results of this cell
#                 have been cached a Google Drive file. Rerunning will result in 
#                 unnecessary network traffic (took me about 4m 30s to send all of these requests)

'''
# get the first 20 reviews for each of the merged professors by using the RMP Reviews API
reviews_base_url = 'https://www.ratemyprofessors.com/paginate/professors/ratings?tid='
reviews = []
for i, tid in enumerate(merged_df['tid']):
  review_url = reviews_base_url + str(tid)
  with urllib.request.urlopen(review_url) as url:
    prof_reviews = json.loads(url.read().decode())

    # the retreived reviews don't include any information about the professor, so add the tid to all
    for review in prof_reviews['ratings']:
      review['tid'] = tid

    reviews.append(prof_reviews)

# this schema specifies to append each rating list to the already merged file
# instead of overwriting the previous one (which is the default)
schema = {
          "properties": {
              "ratings": {
                  "mergeStrategy": "append"
              }             
          }
         }

# merge all of the json objects together, via a chaining method
merger = Merger(schema)
merged_reviews = merger.merge(reviews[0], reviews[1])
for i in range(2, len(reviews)):
  merged_reviews = merger.merge(merged_reviews, reviews[i])

# dump the merged_professors json object into rmp_professors.json file
with open("rmp_reviews.json", "w") as rmp_reviews_json:
     json.dump(merged_reviews, rmp_reviews_json)

# I manually uploaded rmp_reviews.json to my Google Drive, so it can be used in the future
'''
# Out:
# '\n# get the first 20 reviews for each of the merged professors by using the RMP Reviews API\nreviews_base_url = \'https://www.ratemyprofessors.com/paginate/professors/ratings?tid=\'\nreviews = []\nfor i, tid in enumerate(merged_df[\'tid\']):\n  review_url = reviews_base_url + str(tid)\n  with urllib.request.urlopen(review_url) as url:\n    prof_reviews = json.loads(url.read().decode())\n\n    # the retreived reviews don\'t include any information about the professor, so add the tid to all\n    for review in prof_reviews[\'ratings\']:\n      review[\'tid\'] = tid\n\n    reviews.append(prof_reviews)\n\n# this schema specifies to append each rating list to the already merged file\n# instead of overwriting the previous one (which is the default)\nschema = {\n          "properties": {\n              "ratings": {\n                  "mergeStrategy": "append"\n              }             \n          }\n         }\n\n# merge all of the json objects together, via a chaining method\nmerger = Merger(schema)\nmerged_reviews = merger.merge(reviews[0], reviews[1])\nfor i in range(2, len(reviews)):\n  merged_reviews = merger.merge(merged_reviews, reviews[i])\n\n# dump the merged_professors json object into rmp_professors.json file\nwith open("rmp_reviews.json", "w") as rmp_reviews_json:\n     json.dump(merged_reviews, rmp_reviews_json)\n\n# I manually uploaded rmp_reviews.json to my Google Drive, so it can be used in the future\n'

# %%
# get the reviews file from Google Drive, name it rmp_reviews.json
reviews_url = 'https://drive.google.com/file/d/13QDkDkIZDkmzEon0eZYJ3QLVWlrDPtoQ/view?usp=sharing'
reviews_json_drive = drive.CreateFile({'id':'13QDkDkIZDkmzEon0eZYJ3QLVWlrDPtoQ'})
reviews_json_drive.GetContentFile('rmp_reviews.json')

with open('rmp_reviews.json', 'r') as rmp_reviews_json:
  reviews_json = json.load(rmp_reviews_json)['ratings']

reviews_df = pd.json_normalize(reviews_json)

reviews_df
# Out:
#           attendance clarityColor  ... usefulGrouping     tid
# 0                N/A      average  ...         people  523510
# 1      Not Mandatory         poor  ...         people  523510
# 2      Not Mandatory         poor  ...         people  523510
# 3      Not Mandatory         poor  ...         people  523510
# 4      Not Mandatory      average  ...         people  523510
# ...              ...          ...  ...            ...     ...
# 14838            N/A         good  ...         people  530616
# 14839            N/A         good  ...         people  530616
# 14840            N/A         good  ...         person  530616
# 14841            N/A      average  ...         person  530616
# 14842            N/A         good  ...         person  530616
#
# [14843 rows x 32 columns]

# %% [markdown]
# #Transform
# Now we have all of the data loaded into two DataFrames: merged_df and reviews_df
#
# We already did some transforming of the professor data to make our time easier to load the reviews data.
#
# The goals of this section are:
#
# 1. Extract the useful columns and rename columns from reviews_df
# 2. Do the same for merged_df
# 3. Infer the genders and ethnicities for each professor
# 4. Create a department DataFrame by aggregating information from the merged_df
# 5. Create a course DataFrame by aggregating information from the reviews_df
# 6. Get rid of numpy types
#
# End result:
# * Have 4 DataFrames: merged_df, reviews_df, department_df and courses_df

# %%
# make copies of the dfs
reviews_copy = reviews_df.copy()
merged_copy = merged_df.copy()

# %%
# Transform reviews_df by dropping and renaming certain columns
reviews_df = reviews_copy.copy()

# drop the columns that aren't useful/are redundant
unnec_cols = ['unUsefulGrouping',	'usefulGrouping', 'teacher', 'sId', 'rTimestamp', 'rStatus', 'rErrorMsg', 'attendance', 'onlineClass', 
              'helpCount', 'notHelpCount', 'rTextBookUse', 'rWouldTakeAgain', 'takenForCredit', 'rInterest', 'rEasyString', 'rOverallString',
              'clarityColor', 'easyColor', 'helpColor', 'quality', 'teacherRatingTags']
reviews_df.drop(unnec_cols, axis='columns', inplace=True)

# rename the columns that are left to better names
reviews_df.rename(columns={'id':'ReviewID', 'rClarity':'ClarityRating', 'rClass':'CourseID', 'rComments':'Comment', 
                            'rDate':'ReviewDate', 'rEasy' : 'EasyRating', 'rHelpful':'HelpfulRating', 'rOverall':'OverallRating',
                            'teacherGrade':'CourseGrade', 'tid':'ProfID'}, inplace=True)

# convert CourseGrade to a numerical value
letter_num = {'A+':97,'A':93, 'A-':90, 'B+':87,'B':83, 'B-':80, 'C+':77,'C':73, 'C-':70, 'D+':67,'D':63, 'D-':60, 'F':50, 'E':50, 'WD':None, 'N/A':None,
              'Not sure yet':None, 'INC':None, 'Audit/No Grade':None, 'P':70}
reviews_df['CoursePercent'] = reviews_df.apply(lambda row: letter_num[row.CourseGrade], axis='columns')

reviews_df
# Out:
#        ReviewID  ClarityRating     CourseID  ... CourseGrade  ProfID  CoursePercent
# 0      35221583              2      HUMS376  ...           A  523510           93.0
# 1      35087586              1      AFAS306  ...          WD  523510            NaN
# 2      34786511              1      AFAS303  ...           C  523510           73.0
# 3      34777281              1  AFASENGL303  ...          B-  523510           80.0
# 4      34593307              3       GWS312  ...           B  523510           83.0
# ...         ...            ...          ...  ...         ...     ...            ...
# 14838  14918302              5      ENGL300  ...         N/A  530616            NaN
# 14839  14857211              4      ENGL483  ...         N/A  530616            NaN
# 14840  14439152              5       ENG484  ...         N/A  530616            NaN
# 14841  14372588              3      ENGL486  ...         N/A  530616            NaN
# 14842   2990505              5     ENGL458B  ...         N/A  530616            NaN
#
# [14843 rows x 11 columns]

# %%
# Transform merged_df
merged_df = merged_copy.copy()

# drop unused or redundant columns in merged_df
unnec_cols = ['tSid', 'institution_name', 'contentType', 'categoryType', 'tMiddlename', 'Name', 'College Location', 
              'State Fund Ratio', 'FTE', 'College Name', 'rating_class', 'tDept']
merged_df.drop(unnec_cols, axis='columns', inplace=True)

# rename columns in merged_df
merged_df.rename(columns={'tid':'ProfID','tNumRatings':'NumRatings', 'overall_rating':'AverageRating', 
                          'College Name':'CollegeName', 'Primary Title':'Title', 
                          'Annual at Actual FTE':'ActualSalary', 'Annual at Full FTE':'FTESalary'}, inplace=True)

# remove the department name from the end of each professor's Title
merged_df['Title'] = merged_df['Title'].str.split(',', expand=True)[0]

# convert to numeric columns
merged_df.loc[merged_df['AverageRating'] == 'N/A', 'AverageRating'] = 0
merged_df['ActualSalary'] = merged_df['ActualSalary'].str.replace(',', '')
merged_df['FTESalary'] = merged_df['FTESalary'].str.replace(',', '')
merged_df = merged_df.astype({'NumRatings':'int64', 'AverageRating':'float64', 'ActualSalary':'int64', 'FTESalary':'int64'})

merged_copy = merged_df.copy()

merged_df
# Out:
#         FirstName      LastName  ...  FTESalary                   Department
# 0           Yuxuf         Abana  ...      56500             Africana Studies
# 1         Matthew       Abraham  ...      88377                      English
# 2           Corey      Abramson  ...      88777                    Sociology
# 3     Charity-Joy     Acchiardo  ...      88000                    Economics
# 4         Abraham        Acosta  ...      77733       Spanish and Portuguese
# ...           ...           ...  ...        ...                          ...
# 1683      Yitshak         Zohar  ...     114183  Aerospace & Mechanical Engr
# 1684        Marek         Zreda  ...     120240  Hydrology & Atmospheric Sci
# 1685      Adriana  Zuniga Teran  ...      70000      Planning Degree Program
# 1686           Na           Zuo  ...      95000    Agric & Resource Econ-Ins
# 1687        Lynda       Zwinger  ...      98833                      English
#
# [1688 rows x 9 columns]

# %%
# infer the gender for each professor
gender_detector = gender.Detector()
merged_df['InferredGender'] = merged_df.apply(lambda row: gender_detector.get_gender(row.FirstName), axis='columns')
# replace estimates with their full values, and unknown values with Nones
merged_df.loc[merged_df.InferredGender == 'mostly_male', 'InferredGender'] = 'male'
merged_df.loc[merged_df.InferredGender == 'mostly_female', 'InferredGender'] = 'female'
merged_df.loc[merged_df.InferredGender == 'unknown', 'InferredGender'] = None
merged_df.loc[merged_df.InferredGender == 'andy', 'InferredGender'] = None

print(f"{merged_df['InferredGender'].isnull().sum()/len(merged_df.index) * 100:.2f}% of professors are missing their gender")

merged_df
# Out:
# 10.72% of professors are missing their gender
#         FirstName      LastName  ...                   Department  InferredGender
# 0           Yuxuf         Abana  ...             Africana Studies            None
# 1         Matthew       Abraham  ...                      English            male
# 2           Corey      Abramson  ...                    Sociology            male
# 3     Charity-Joy     Acchiardo  ...                    Economics            None
# 4         Abraham        Acosta  ...       Spanish and Portuguese            male
# ...           ...           ...  ...                          ...             ...
# 1683      Yitshak         Zohar  ...  Aerospace & Mechanical Engr            None
# 1684        Marek         Zreda  ...  Hydrology & Atmospheric Sci            male
# 1685      Adriana  Zuniga Teran  ...      Planning Degree Program          female
# 1686           Na           Zuo  ...    Agric & Resource Econ-Ins            None
# 1687        Lynda       Zwinger  ...                      English          female
#
# [1688 rows x 10 columns]

# %%
# infer ethnicity for each professor
ethnicities = ['pctwhite', 'pctblack', 'pctapi', 'pctaian', 'pct2prace', 'pcthispanic']

# put the percent of each ethnicity for each professor into merged_df
merged_df = census_ln(merged_df, 'LastName', 2010)

# convert each pct column to a str because NaN values aren't being replaced using normal means (these are object typed fields)
merged_df = merged_df.astype({'pctwhite':'str', 'pctblack':'str', 'pctapi':'str', 'pctaian':'str', 'pct2prace':'str', 'pcthispanic':'str'})

# convert each invalid column value to a 0
for eth in ethnicities:
  merged_df.loc[merged_df[eth] == 'nan', eth] = 0
  merged_df.loc[merged_df[eth] == '(S)', eth] = 0

# convert the pct columns to floats now that we have removed NaNs and (S)s
merged_df = merged_df.astype({'pctwhite':'float64', 'pctblack':'float64', 'pctapi':'float64', 'pctaian':'float64', 'pct2prace':'float64', 'pcthispanic':'float64'})

# find the maximum confidence for each professor's ethnicity
merged_df['EthnicityConfidence'] = merged_df[['pctwhite', 'pctblack', 'pctapi', 'pctaian', 'pct2prace', 'pcthispanic']].max(axis='columns')

# assign the correct ethnicity to the professor based on the max confidence found
merged_df['InferredEthnicity'] = merged_df.apply(lambda row: row[row == row['EthnicityConfidence']].index[0], axis=1)

# remove the 'pct' from the beginning of the ethincities
for eth in ethnicities:
  merged_df.loc[merged_df['InferredEthnicity'] == eth, 'InferredEthnicity'] = eth[3:]

# replace all None ethnicities with nonwhite (new ethnicity) because I am assuming the data is pulling mostly from white surnames, 
# so most of the misses will be non-white
merged_df.loc[merged_df['EthnicityConfidence'] == 0, 'InferredEthnicity'] = 'nonwhite'

# drop the pct columns since they are no longer needed
merged_df.drop(ethnicities, axis='columns', inplace=True)

merged_df
# Out:
#         FirstName      LastName  ...  EthnicityConfidence  InferredEthnicity
# 0           Yuxuf         Abana  ...                 0.00           nonwhite
# 1         Matthew       Abraham  ...                45.00              white
# 2           Corey      Abramson  ...                91.14              white
# 3     Charity-Joy     Acchiardo  ...                 0.00           nonwhite
# 4         Abraham        Acosta  ...                89.48           hispanic
# ...           ...           ...  ...                  ...                ...
# 1683      Yitshak         Zohar  ...                94.37              white
# 1684        Marek         Zreda  ...                 0.00           nonwhite
# 1685      Adriana  Zuniga Teran  ...                 0.00           nonwhite
# 1686           Na           Zuo  ...                90.67                api
# 1687        Lynda       Zwinger  ...                97.52              white
#
# [1688 rows x 12 columns]

# %%
# create the department dataframe
department_df = pd.DataFrame({'Department':merged_df['Department'].unique()})

# get the number of professors in each department
aggs = pd.merge(department_df, merged_df, how='inner', on='Department').groupby('Department').agg(NumProfessors=('Department', 'count'), 
                                                                                                  AvgRating=('AverageRating', 'mean'),
                                                                                                  AvgFTESalary=('FTESalary', 'mean'),
                                                                                                  TotalProfPay=('ActualSalary', 'sum'))
department_df = pd.merge(department_df, aggs, how='inner', on='Department')
ethnicities = ['white', 'black', 'api', 'aian', '2prace', 'hispanic', 'nonwhite']
for eth in ethnicities:
  eth_aggs = pd.merge(department_df, merged_df[merged_df['InferredEthnicity'] == eth], 
                    how='inner', on='Department').groupby('Department').agg(
                        count=('InferredEthnicity', 'count')
                    )
  eth_aggs.columns = ['Count'+eth]
  department_df = pd.merge(department_df, eth_aggs, how='left', on='Department').fillna(0)

  department_df['Percent'+eth] = department_df.apply(lambda row: row['Count'+eth] / row['NumProfessors'], axis='columns')
  department_df.drop(['Count'+eth], axis='columns', inplace=True)

department_df
# Out:
#                          Department  ...  Percentnonwhite
# 0                  Africana Studies  ...         0.230769
# 1                           English  ...         0.193182
# 2                         Sociology  ...         0.055556
# 3                         Economics  ...         0.250000
# 4            Spanish and Portuguese  ...         0.205882
# ..                              ...  ...              ...
# 193       Environmental Science-Ext  ...         0.000000
# 194                  Otolaryngology  ...         0.000000
# 195  Facilities Mgmt-Maint Services  ...         0.000000
# 196  Asthma/Airway Disease Rsch Ctr  ...         0.000000
# 197       Agric & Resource Econ-Ins  ...         0.000000
#
# [198 rows x 12 columns]

# %%
# create courses df
courses_df = pd.DataFrame({'CourseID' : reviews_df['CourseID'].unique()})

courses_df = pd.merge(reviews_df, courses_df, how='inner', on='CourseID').groupby('CourseID').agg(AvgEasy=('EasyRating', 'mean'),
                                                                                            AvgHelpful=('HelpfulRating', 'mean'),
                                                                                            AvgClarity=('ClarityRating', 'mean'),
                                                                                            AvgOverall=('OverallRating', 'mean'),
                                                                                            MostCommonProf=('ProfID', lambda x: pd.Series.mode(x)[0]),
                                                                                            AvgGrade=('CoursePercent', 'mean'),
                                                                                            NumRatings=('ReviewID', 'count'))

# get the department of the most common professor for each course
courses_df.reset_index(level=0, inplace=True)
prof_dept = merged_df[['ProfID', 'Department']]
courses_df = pd.merge(courses_df, prof_dept, how='inner', left_on='MostCommonProf', right_on='ProfID')

courses_df
# Out:
#      CourseID   AvgEasy  ...   ProfID                      Department
# 0        100A  3.000000  ...  2297258   Sch Theatre Film & Television
# 1     FTV150B  2.000000  ...  2297258   Sch Theatre Film & Television
# 2        100B  4.000000  ...  2220229   Sch Theatre Film & Television
# 3      FTV100  4.666667  ...  2220229   Sch Theatre Film & Television
# 4     FTV100A  4.000000  ...  2220229   Sch Theatre Film & Television
# ...       ...       ...  ...      ...                             ...
# 3702  TTE596C  4.000000  ...  1674761  Teachg Learning Sociocult Stds
# 3703  WFSC385  3.000000  ...  2590803  Sch of Nat Resource&Enviro-Res
# 3704  WFSC444  3.500000  ...  1279959  Sch of Nat Resource&Enviro-Res
# 3705  WFSC447  3.000000  ...  1279959  Sch of Nat Resource&Enviro-Res
# 3706   WSM460  4.250000  ...  2087404     Hydrology & Atmospheric Sci
#
# [3707 rows x 10 columns]

# %%
# numpy types muck everything up
import datetime as dt
def numpy_to_python_types(df):
  for col in df.columns:
    t = df[col].dtype

    if t == 'int64' or t == 'float64':
      df = df.astype({col: 'object'})

  return df

merged_df = numpy_to_python_types(merged_df)

reviews_df = reviews_df.where(pd.notnull(reviews_df), None)
reviews_df = numpy_to_python_types(reviews_df)

department_df = numpy_to_python_types(department_df)

courses_df = courses_df.replace({np.nan: None})
courses_df = numpy_to_python_types(courses_df)
# Out:
#        ReviewID ClarityRating     CourseID  ... CourseGrade  ProfID CoursePercent
# 0      35221583             2      HUMS376  ...           A  523510          93.0
# 1      35087586             1      AFAS306  ...          WD  523510          None
# 2      34786511             1      AFAS303  ...           C  523510          73.0
# 3      34777281             1  AFASENGL303  ...          B-  523510          80.0
# 4      34593307             3       GWS312  ...           B  523510          83.0
# ...         ...           ...          ...  ...         ...     ...           ...
# 14838  14918302             5      ENGL300  ...         N/A  530616          None
# 14839  14857211             4      ENGL483  ...         N/A  530616          None
# 14840  14439152             5       ENG484  ...         N/A  530616          None
# 14841  14372588             3      ENGL486  ...         N/A  530616          None
# 14842   2990505             5     ENGL458B  ...         N/A  530616          None
#
# [14661 rows x 11 columns]

# %% [markdown]
# #Load
# Now, we have merged_df (for professors), reviews_df, department_df, and courses_df.
#
# So we need to create tables and insert all of the data into them.
#
# End result:
# * Have 4 tables: Professor, Review, Department, Course

# %%
import mysql.connector as mysql
import pandas as pd
# SQL function definitions
def get_conn_cur(): # define function name and arguments (there aren't any)
  # Make a connection
  conn = mysql.connect(host="54.184.86.6", 
                       database="rmp_ista",
                       user="select_rmp",
                       password="select_rmp")

  cur = conn.cursor()   # Make a cursor after

  return(conn, cur)   # Return both the connection and the cursor

def run_query(query_string):
  conn, cur = get_conn_cur() # get connection and cursor

  cur.execute(query_string) # executing string as before

  my_data = cur.fetchall() # fetch query data as before

  # here we're extracting the 0th element for each item in cur.description
  colnames = [desc[0] for desc in cur.description]

  cur.close() # close
  conn.close() # close

  return pd.DataFrame(data=my_data, columns=colnames)
  #return(colnames, my_data) # return column names AND data

# make sql_head function
def sql_head(table_name):
  return run_query(f"SELECT * FROM {table_name} LIMIT 5")

# Check table_names
def get_table_names():
  conn, cur = get_conn_cur() # get connection and cursor

  # query to get table names
  table_name_query = """SELECT table_name FROM information_schema.tables
       WHERE table_schema = 'public' """

  cur.execute(table_name_query) # execute
  my_data = cur.fetchall() # fetch results

  cur.close() #close cursor
  conn.close() # close connection

  return(my_data) # return your fetched results

# %%
# create the tables

conn, cur = get_conn_cur()

#cur.execute("DROP TABLE Professor")
#cur.execute("DROP TABLE Course")
#cur.execute("DROP TABLE Review")
#cur.execute("DROP TABLE Department")

# professor table
print(merged_df.columns)
create_professor = """CREATE TABLE Professor(
  FirstName VARCHAR(50),
  LastName VARCHAR(50),
  ProfID INT PRIMARY KEY,
  NumRatings INT,
  AverageRating REAL,
  Title VARCHAR(100),
  AcutalSalary INT,
  FTESalary INT,
  Department VARCHAR(100),
  InferredGender VARCHAR(10),
  EthnicityConfidence REAL,
  InferredEthnicity VARCHAR(10)
)"""

cur.execute(create_professor)

# create courses
print(courses_df.columns)
create_course = """CREATE TABLE Course(
  CourseID VARCHAR(20) PRIMARY KEY,
  AvgEasy REAL,
  AvgHelpful REAL,
  AvgClarity REAL,
  AvgOverall REAL,
  MostCommonProf INT,
  AvgGrade REAL,
  NumRatings INT,
  ProfID INT,
  Department VARCHAR(100)
)
"""
cur.execute(create_course)

# create reviews
print(reviews_df.columns)
create_review = """CREATE TABLE Review(
  ReviewID INT PRIMARY KEY,
  ClarityRating REAL,
  CourseID VARCHAR(20),
  Comment VARCHAR(5000),
  ReviewDate DATE,
  EasyRating REAL,
  HelpfulRating REAL,
  OverallRating REAL,
  CourseGrade VARCHAR(20),
  ProfID INT,
  CoursePercent REAL
)
"""
cur.execute(create_review)

# create departments
print(department_df.columns)
create_department = """CREATE TABLE Department(
  Department VARCHAR(100) PRIMARY KEY,
  NumProfessors INT,
  AvgRating REAL,
  AvgFTESalary REAL,
  TotalProfPay INT,
  Percentwhite REAL,
  Percentblack REAL,
  Percentapi REAL,
  Percentaian REAL,
  Percent2prace REAL,
  Percenthispanic REAL,
  Percentnonwhite REAL
)
"""

cur.execute(create_department)

cur.close()
conn.commit()
conn.close()
# Out:
# Index(['CourseID', 'AvgEasy', 'AvgHelpful', 'AvgClarity', 'AvgOverall',
#        'MostCommonProf', 'AvgGrade', 'NumRatings', 'ProfID', 'Department'],
#       dtype='object')
# Index(['ReviewID', 'ClarityRating', 'CourseID', 'Comment', 'ReviewDate',
#        'EasyRating', 'HelpfulRating', 'OverallRating', 'CourseGrade', 'ProfID',
#        'CoursePercent'],
#       dtype='object')
# Index(['Department', 'NumProfessors', 'AvgRating', 'AvgFTESalary',
#        'TotalProfPay', 'Percentwhite', 'Percentblack', 'Percentapi',
#        'Percentaian', 'Percent2prace', 'Percenthispanic', 'Percentnonwhite'],
#       dtype='object')

# %%
# need to be able to adapt numpy types so that postgres can handle them
# source: https://stackoverflow.com/questions/50626058/psycopg2-cant-adapt-type-numpy-int64
import numpy as np
# from psycopg2.extensions import register_adapter, AsIs
# register_adapter(np.int64, psycopg2._psycopg.AsIs)

# %%
# insert into professor table
conn, cur = get_conn_cur()

merged_df = merged_df.drop_duplicates('ProfID', keep='first')
#cur.execute("DELETE FROM Professor")

prof_tuples = merged_df.to_records(index=False)

for prof in prof_tuples:
  query = "INSERT INTO Professor VALUES(%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"

  cur.execute(query, tuple(prof))

cur.close()
conn.commit()
conn.close()
# Out:
# FirstName              object
# LastName               object
# ProfID                 object
# NumRatings             object
# AverageRating          object
# Title                  object
# ActualSalary           object
# FTESalary              object
# Department             object
# InferredGender         object
# EthnicityConfidence    object
# InferredEthnicity      object
# dtype: object

# %%
sql_head('Professor')
# Out:
#   FirstName  LastName  ...  EthnicityConfidence  InferredEthnicity
# 0    Joseph  Tolliver  ...                48.87              black
# 1   Suzanne   Delaney  ...                83.59              white
# 2    Sandra      Barr  ...                82.69              white
# 3   Patrick  McDonald  ...                76.65              white
# 4    Thomas    Wilson  ...                67.36              white
#
# [5 rows x 12 columns]

# %%
# insert into course table

conn, cur = get_conn_cur()

courses_df = courses_df.drop_duplicates('CourseID', keep='first')
#cur.execute("DELETE FROM Course")

course_tuples = courses_df.to_records(index=False)
for course in course_tuples:
  query = "INSERT INTO Course VALUES(%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"
  cur.execute(query, tuple(course))

cur.close()
conn.commit()
conn.close()

# %%
sql_head('Course')
# Out:
#    CourseID   AvgEasy  ...   ProfID                      Department
# 0      100A  3.000000  ...  2297258   Sch Theatre Film & Television
# 1      100B  4.000000  ...  2220229   Sch Theatre Film & Television
# 2       101  2.700000  ...  1670556          Spanish and Portuguese
# 3      101A  2.923077  ...  1491674                         English
# 4  101A101B  4.000000  ...  1154235  Chemistry & Biochemistry - Sci
#
# [5 rows x 10 columns]

# %%
# insert into department table

conn, cur = get_conn_cur()

department_df = department_df.drop_duplicates('Department', keep='first')
#cur.execute("DELETE FROM Department")

department_tuples = department_df.to_records(index=False)
for dept in department_tuples:
  query = "INSERT INTO Department VALUES(%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"
  cur.execute(query, tuple(dept))

cur.close()
conn.commit()
conn.close()

# %%
sql_head('Department')
# Out:
#                        Department  ...  Percentnonwhite
# 0         Academic Administration  ...         0.000000
# 1  Academic Inits & Stdnt Success  ...         0.000000
# 2   Access & Information Services  ...         1.000000
# 3    Administration and Athletics  ...         0.000000
# 4     Aerospace & Mechanical Engr  ...         0.482759
#
# [5 rows x 12 columns]

# %%
# insert into review table

conn, cur = get_conn_cur()

reviews_df = reviews_df.drop_duplicates('ReviewID', keep='first')
#cur.execute("DELETE FROM Review")

review_tuples = reviews_df.to_records(index=False)
for rev in review_tuples:
  query = "INSERT INTO Review VALUES(%s, %s, %s, %s, STR_TO_DATE(%s, '%m/%d/%Y'), %s, %s, %s, %s, %s, %s)"

  cur.execute(query, tuple(rev))

cur.close()
conn.commit()
conn.close()
# Out:
# Streaming output truncated to the last 5000 lines.
# (25930715, 5, 'CE214', "Dean is the fricken man. Ever since I took statics I see statics everywhere. He really gets into statics and you can tell he is genuinely excited to teach the subject. It's a tough class, but he is fair and really wants you to leave the course understanding the material so you can apply it in future classes and the professional world.", '01/12/2016', 4.0, 5, 5.0, 'B+', 2097441, 87.0)
# (25874183, 4, 'CE214', "He loves the material that he teaches. I have learned more in this class than I have in any other class. He doesn't make the class ridiculously easy but he is helpful and open to questions.  He is more than fair and allows cheat sheets for all exams. There is also weekly homework. I would recomend him to someone who wants to be taught the material.", '01/04/2016', 3.0, 5, 4.5, 'B', 2097441, 83.0)
# (34959446, 4, 'BCOM214', 'touch on grading,but nice teacher', '07/08/2021', 4.0, 4, 4.0, 'B+', 2558116, 87.0)
# (32706677, 5, 'BCOM214', 'Erin was an amazing professor and made each class fun. The assignment are not that hard and the tests are easy if you regularly attend class. Erin gives great feedback and I looked forward to going to this class each week. I would 10/10 recommend taking BCOM with Erin.', '12/18/2019', 2.0, 5, 5.0, 'A+', 2558116, 97.0)
# (34369301, 1, 'AME536', 'Bernard is the least helpful and most arrogant professor that I have ever had. He is good at lecturing but his is not interested on teaching or holding office hours. He wants everything to be done his ways and homeworks feel as if you are fishing for an answer. He doesnt provide homework solutions or any constructive feedback.', '02/17/2021', 3.0, 1, 1.0, 'B', 2600983, 83.0)
# (28655469, 5, 'PA445', 'EXTREMELY Interesting! Professor Parin is not Tech savvy, so you must attend lectures to get the content or get the textbook (not mandatory) to read what is talked about in class. He tells you exactly what is on his quizzes so pay attention and he does not use D2L. We also get to tour the state prison since he is a retired warden.', '09/02/2017', 1.0, 5, 5.0, 'Not sure yet', 2278565, None)
# (27115428, 1, 'ANTH150B1', "His lectures are the most boring things in the world. We are over half way through the term and I still don't know what the class is about. There's written homework very week which most answers you can find online but his TAs do all of his work for him. He's extremely inappropriate too.", '11/02/2016', 3.0, 1, 1.0, 'N/A', 447318, None)
# (25515889, 2, 'ANTHRO150B', "In ANTHO150B you think that it will be easy but trust me it isn't. Each week you have to answer 4 weekly questions that are worth 60% of your grade. Professor Park does not grade these questions but the Teacher Aide's who do grade them are very harsh. Be aware if you take this class because the weekly questions need to be specific. ", '12/01/2015', 4.0, 3, 2.5, 'B-', 447318, 80.0)
# (25214097, 2, '150B1', 'This professor is very confusing to understand. Sometimes I do not understand what he is taking about. I never thought inequality would be so boring. Turns out that the word "Okay" get old really fast.', '09/28/2015', 1.0, 1, 1.5, 'A+', 447318, 97.0)
# (24350955, 2, '160', 'Loved the topics discussed in class, super easy class if you show up and do the readings easy A. He always will answer emails and is overall hilarious. He will sometimes get side-tracked and tell random stories which is fun. Haha would definitely recommend for a GPA booster. ', '02/01/2015', 1.0, 4, 3.0, 'A+', 447318, 97.0)
# (22697943, 1, 'ANTH150B', 'A lot of economics terms. It\'s basically a common sense course, you don\'t really need to know the material. Sometimes lecture can be interesting, but 99% of the time all you hear is him saying, "okay."', '01/05/2014', 2.0, 2, 1.5, 'N/A', 447318, None)
# (22477541, 1, 'ANTH424', 'He does not seem to put a lot of effort into teaching, and he just ignored my emails when I wrote to him with questions.', '12/09/2013', 3.0, 1, 1.0, 'N/A', 447318, None)
# (22241564, 2, 'ANTH409', 'Boring content and the professor goes on many tangents.  However, in class he gives major hints for the midterm and final.  If you go to class and pay attention you will get an A.', '11/01/2013', 2.0, 4, 3.0, 'A+', 447318, 97.0)
# (22176748, 1, 'ANTH150B1', 'In short, I hate this class. The subject matter is uninspiring and not what I expected from a class called "Many Ways of Being Human". If I wanted to take an econ course, that\'s what I would have signed up for. Dr. Park is nice, but a boring lecturer. One perk of the class though is the text is free. That\'s pretty much the only redeeming quality.', '10/14/2013', 5.0, 1, 1.0, 'N/A', 447318, None)
# (21189871, 3, 'ANTH150B', 'Not going to lie, this class was a pain. Dr Park is very smart but this makes the subject material way too complicated for normal students with no interest in economic anthropology. Best part is there are no tests, but the 4 essay questions you answer every week are seriously torture. Avoid if you can.', '12/31/2012', 2.0, 4, 3.5, 'N/A', 447318, None)
# (20768977, 2, 'ANTH150B', "Dr.Park obviously knows what he's talking about but it is challenging to stay awake in this class. I would say it is very easy but it will basically depend on your TA. I had Satoshi Abe and while he's nice and very open for help, he takes his job very seriously so the weekly questions he grades must be complete. I wouldn't take this class again...", '11/02/2012', 3.0, 1, 1.5, 'N/A', 447318, None)
# (20472700, 5, 'ANTHECO', 'Economic Anthro - not a class I wanted to take. It changed my world; such an amazing class. Park was clear, engaged, calm and extremely accessible. I felt I learned more in this class than most. Books were useful; I still have them. I cite stuff from this class all the time - really!', '07/07/2012', 3.0, 5, 5.0, 'N/A', 447318, None)
# (19842562, 3, 'ANTH150A', 'Extremely easy Gen Ed. Take it, easy A. Your grade is mostly attendance so show up. The rest is based on four questions a week online. So easy.', '02/20/2012', 1.0, 3, 3.0, 'N/A', 447318, None)
# (17309309, 5, 'INDV101', 'Great teacher. Ateendance not required. No idterm and only take final if want to help your grade. Easy A', '06/06/2010', 2.0, 5, 5.0, 'N/A', 447318, None)
# (17309294, 5, 'INDV102', 'Very nice teacher and extemely willing to help you. Attendance not required. He gives 5 questions per week and no mid term and you only have to take the final if you want to improve your grade.', '06/06/2010', 1.0, 5, 5.0, 'N/A', 447318, None)
# (17073591, 1, 'INDIV102', "Dr. Park is a good professor, but he is a pure genius. He dumbs down his lectures but they are still impossible to understand. We had to respond to 5 questions a week but they had to be really extensive answers. The grade you get in the class completely depends on your TA because they grade your weekly responses. I wouldn't recommend the class.", '04/28/2010', 4.0, 2, 1.5, 'N/A', 447318, None)
# (16574295, 4, 'INDV102', 'extremely easy class. You just have to do the homework and make sure someone signs you in for lectures and go to the section classes. The homework is so easy, he gives you what exact pages to read to get the points for the homework. I barely went to class, did all the homework and got an A. take this class!', '12/16/2009', 1.0, 4, 4.0, 'N/A', 447318, None)
# (16566018, 2, 'INDV102', 'This class was so easy, all you had to do was the 5 essay questions a week homework and show up to discussion. Time in lecture can be spent on a laptop and you can still get an A. No quizzes, no big papers, and the final is optional.', '12/15/2009', 1.0, 3, 2.5, 'N/A', 447318, None)
# (16546713, 2, 'INDV102H', 'Had to write 4 page papers WEEKLY. However, I feel like I BSed at least half of what I was saying and got an A. He gave everyone As as long as they turned their papers in. Rarely went to class in the last half of the semester. He is just really confusing but very easy teacher. No final either', '12/14/2009', 1.0, 2, 2.0, 'N/A', 447318, None)
# (16530669, 1, 'INDIV102', 'terrible class,  None of his lectures had anything to do with our weekly questions.  No TESTS, OR QUIZES.  however you had to write 5 1/2 page responses weekly.  DO NOT TAKE THIS CLASS', '12/11/2009', 4.0, 1, 1.0, 'N/A', 447318, None)
# (16436266, 2, 'INDV102', "i found this class to be terribly boring with no overall objective. Dr. Park seems like a nice person, i'm sure he is, but he rambles in his lectures and never seems to get anywhere. this class turned out to be more of an econ course than anything, i found there to be no connection between week to week lectures/questions, easy class even not trying", '11/29/2009', 3.0, 2, 2.0, 'N/A', 447318, None)
# (33443713, 5, 'GRK201', "Dr. Park is amazing. Ancient Greek is such an intimidating language, and she very consciously teaches so as to make the material accessible without watering it down. If you're struggling, she actively encourages students to come to her office hours for help, and when you come, she is very helpful (and just a good person? lol). A rare gem!", '06/17/2020', 4.0, 5, 5.0, 'A', 2080039, 93.0)
# (31011869, 5, 'GRK101', "Dr. Park is an amazing teacher. Classical Greek is not an easy language, and the course moves very fast, but she works with you and gives plenty of opportunity to make up lost points on quizzes and tests. Class is necessary to pass, missing even one and it's easy to fall behind, but the lectures are short and helpful. Will take again.", '12/13/2018', 5.0, 5, 5.0, 'B', 2080039, 83.0)
# (30060596, 4, 'CLAS160D', 'Very easy class but you NEED to take notes to do well.', '05/10/2018', 2.0, 4, 4.0, 'A', 2080039, 93.0)
# (30034332, 4, 'CLAS160D2', "Personality - bubbly, sweet Class - lectures daily, lots of clicker ?'s for participation, slideshows give overview but not super helpful study material Book - helpful but not required, you could google stories Tests - long, study if you want A's Easy class overall, would take another class from her.", '05/09/2018', 2.0, 4, 4.0, 'A-', 2080039, 90.0)
# (27145768, 3, 'GRK101', 'Prof. Park is a nice, caring individual; as a professor, she is a little clueless of her students at times. She can be very vague at times with the lessons. She expects a lot with a very short period of time- unit quizzes every week, chapter homework every night. Good thing, though, is she offers a lot of extra credit- and it is very needed.', '11/07/2016', 3.0, 3, 3.0, 'N/A', 2080039, None)
# (26486855, 3, 'CLAS160D', "Lectures are boring and tests are pretty tough considering this is only a gen ed course. You don't need the textbook. Her PowerPoint slides are useless when studying for the tests, so you have to make sure to take notes on what she says in lecture. You won't pass if you skip class.", '05/06/2016', 3.0, 3, 3.0, 'N/A', 2080039, None)
# (26446247, 1, 'CLAS160D2', "Ummm yea she's a good person but her lectures are longgggggggg. She doesn't really clarify anything either, which makes learning the material even worse.", '05/03/2016', 3.0, 1, 1.0, 'C+', 2080039, 77.0)
# (26445911, 3, 'CLAS160D2', 'This teacher honestly has boring lectures but if you attend class and pay attention you can pass the class. She is very fair in grading.', '05/03/2016', 4.0, 2, 2.5, 'N/A', 2080039, None)
# (26433114, 3, 'CLAS160D2', "Professor Park is okay with her teaching. Her lectures are long, boring, and confusing to retain. The TAs are pretty hard graders and they give you somewhat of a good feedback on your response essays. Exams are multiple choice and written (defining images and characters). Overall, you don't need the textbook for this class, but to just study!!", '05/02/2016', 3.0, 3, 3.0, 'B+', 2080039, 87.0)
# (26369105, 1, 'CLAS160D', 'Arum Park is hands down the worst professor I have ever had. Her lectures are convoluted as well as disorganized. She constantly brings up inappropriate discussion topics that waste precious class time. I am not a disgruntled student with a failing grade, rather a student that cares about others and just wants to make sure no one wastes their time', '04/25/2016', 1.0, 1, 1.0, 'A+', 2080039, 97.0)
# (26327107, 3, 'CLAS160D', 'There is a reading every night before the lecture, some of them arent that bad. You need the textbook because she uses it to make test questions. Also, every class is mandatory, she takes attendance everyday. If you pay attention and do the short answer questions and short quizzes you can easily get a B. But, she is a tough grader.', '04/19/2016', 2.0, 2, 2.5, 'B', 2080039, 83.0)
# (26253720, 3, 'CLAS160D', "She likes to interact with the class via TopHat so beware the subscription cost.  Easy enough but there is some content that isn't common knowledge so you do have to pay attention.", '04/07/2016', 3.0, 3, 3.0, 'Not sure yet', 2080039, None)
# (25982612, 3, 'CLAS160D2', "She is very enthusiastic and is great to capture your attention. Her class includes a LOT of reading, so if you're not a reader I wouldn't recommend this class as most of the homework is reading and her quizzes/test are  also based on the book she assigns.", '01/22/2016', 3.0, 4, 3.5, 'N/A', 2080039, None)
# (25590819, 5, 'CLAS346', 'Prof Park is awesome. She clarifies all questions your have and engages students in class discussions. She will look at your ideas from your point of view and try to understand how you see it that way instead of telling you "No that\'s wrong, it\'s only this answer" like other Classic professors tend to do. If you don\'t do the reading, SparkNotes ', '12/08/2015', 2.0, 5, 5.0, 'A', 2080039, 93.0)
# (34097351, 1, 'HPS350', "I wish I could say I really enjoyed Dr. Parker's class, but she just made it so difficult to. The content itself was quite interesting and I do think she is well versed, but she is not approachable at all. She almost comes off as sassy but in a rude way. She's also a really tough grader and made a class that should be enjoyable, quite difficult.", '12/16/2020', 4.0, 1, 1.0, 'B', 683640, 83.0)
# (33560923, 1, 'HPS350', 'Shes not very helpful! Does not care for her students much. If you cant afford the materials she will simply tell you to drop her class. I did poor in the attendance area and came out with a B and Aced her finals! Final is very easy! All the answers are in her book. Sucks shes the only teacher for HPS 350.', '08/05/2020', 2.0, 1, 1.0, 'B-', 683640, 80.0)
# (33291851, 5, 'HPS350', 'This class requires a lot of work and communication. Groups are randomly assigned but if you end up with a terrible group office hours will be your best friend. She offered up to 60 points of extra credit. She truly wants everyone to succeed and will help in any way she can! She is so sweet and I came to really admire her.', '05/14/2020', 4.0, 5, 5.0, 'A', 683640, 93.0)
# (33223642, 1, 'HPS350', 'Dr. Parkers was the worst professor I have ever had in my college experience. The entire grading system is based off of two group projects that require massive amounts of work, with little to no helpful feedback from her. Her lectures are monotone and she requires you to buy her book and TopHat. If your not required to take this class, do not.', '05/06/2020', 5.0, 1, 1.0, 'C-', 683640, 70.0)
# (32605895, 2, 'CPH350', "Literally such a horrible class. Dr. Parker as a person is okay but the class structure is so terribly set up. The homework is confusing, the group projects are tedious and hard because feedback is poor and grading is hard. There's little opportunity to show yourself as a student, you're constantly relying on other people. Avoid at all costs!!!!!", '12/11/2019', 4.0, 2, 2.0, 'Not sure yet', 683640, None)
# (32026607, 5, 'CPH350', 'Yes, your grade is determined by your group. If your group sucked, like mine, TELL HER AND SHE WILL HELP YOU. You will then submit your work separate from the rest of the group. For years she has been the professor whose students say &quot;wow what I learned in your class I use in the field&quot;. Ask around and staff will confirm.', '06/14/2019', 4.0, 5, 5.0, 'B', 683640, 83.0)
# (32586223, 1, 'MIS111', 'Dr. Patton is a horrible professor. He treats his students like they are in 5th grade and calls out anyone who is wearing headphones or even talking during class... not to mention there are 600 people in each class. He goes through the material way too fast and it is impossible to retain the information he &quot;teaches&quot;', '12/10/2019', 4.0, 1, 1.0, 'B', 880998, 83.0)
# (32450147, 1, 'MIS111', 'so bad and boring. he will call you out and he is condescending. mis111 is pretty straightforward, but mis112 is insanely hard to understand', '11/20/2019', 3.0, 1, 1.0, 'C', 880998, 73.0)
# (32448985, 1, 'MIS111', 'Always calls people out for wearing headphones, and some of the people dont even have headphones in and its just awkward...', '11/20/2019', 5.0, 1, 1.0, 'C-', 880998, 70.0)
# (32274078, 1, 'MIS111', "Very boring, condescending, rude - goes way too fast and sometimes I can't even understand him", '10/09/2019', 3.0, 1, 1.0, 'N/A', 880998, None)
# (31843152, 2, 'MIS111', "Dr. Patton's class was boring and i didn't learn anything AT ALL. The ABPs are busy work, but u'll get full points even if half of what you wrote doesnt make sense,which is what i did. Exams are heavy because you have to sit down and memorize about 7 previous exams. Use quizlet for icqs and pars. Do icqs at home cause u wont learn anything in class", '05/11/2019', 2.0, 2, 2.0, 'A', 880998, 93.0)
# (31709315, 3, 'MIS111', 'boring- mark is so monotoned. the exams can be difficult when you leave it to the last second to study... start preparing for exam at least 3/4 days before becuase it gets overwhelming all the material to study. attendance is not really mandatory-- theres in class quizzes every time taken at the end of class.. if u skip make sure ur on ua wifi', '04/29/2019', 3.0, 3, 3.0, 'A-', 880998, 90.0)
# (31697934, 4, 'MIS111', '3/4 tests, 3 projects, hw quizzes &amp; in-class assignments. Attempt to do every single ICQ &amp; PAR b/c tests consist of questions from them. Project instructions can be confusing but they are easy. You are graded more on completion than quality.', '04/28/2019', 3.0, 4, 4.0, 'A+', 880998, 97.0)
# (31578780, 3, 'MIS111', 'I did not learn a single thing in this class besides not to click on links in emails. As long as you get the Socratic app to do in class quizzes and at home quizzes you should be fine. To study for tests just memorize all of the quiz questions (I made quizlets and got As and Bs on my tests although the average is a C). Projects are easy.', '04/12/2019', 3.0, 3, 3.0, 'N/A', 880998, None)
# (31221051, 2, 'MIS111', 'Dr. Patton knows the material very well. However, he is very monotone and goes over the material pretty quickly. He definitely gets irritated with the class at times and will call someone out if they have headphones in.', '01/08/2019', 3.0, 2, 2.0, 'A', 880998, 93.0)
# (30660194, 1, 'MIS111', 'Hard to listen to because he always screams into the microphone. Teaches very, very aggressively and condescendingly during his lectures. He will reference terms and vocabulary that he assumes you know, and when you do not know what he is talking about he will get even more mad and scream more into the mic. Get ready to feel bad about yourself.', '11/05/2018', 3.0, 1, 1.0, 'N/A', 880998, None)
# (30542023, 2, 'MIS111', "Patton is one of two teachers for the MIS class, and personally, he isn't my favorite. He knows what he is talking about, but doesn't explain it well. It's like the mentality that he knows it, so everyone should. He goes WAYYYY to fast in lectures, so I recommend just listening to his lectures instead of trying to write down notes at the same time", '10/04/2018', 3.0, 2, 2.0, 'N/A', 880998, None)
# (30014932, 3, 'MIS111', "Class in itself was very easy, show up, do the clickers, review previous exams, do the ABP's and get an A. Patton is very monotone which can get quite mundane, but still an easy class. Doesn't curve grades so don't slack off and do the work and you'll get the A you deserve.", '05/07/2018', 1.0, 3, 3.0, 'A', 880998, 93.0)
# (29669045, 1, 'MIS111', "MIS 111 is a pretty easy course, just come to class for clicker points, read and do the PARs, and keep up with the homework and you'll pass. Patton is one of two professors and honestly the worst of the pair. Not only is he boring but he constantly comes in with an attitude and makes the lecture a bore.", '03/19/2018', 2.0, 1, 1.0, 'B', 880998, 83.0)
# (29441561, 5, 'MIS111', 'Great Professor, cares about what he teaches and very helpful. The class is easy just do your assignments on time and go to class to get attendance points. I went to the office hours once and he was really helpful and patient and made everything I did not understand clear. Highly recommended.', '01/12/2018', 1.0, 5, 5.0, 'A', 880998, 93.0)
# (29214354, 4, 'MIS111', "He makes the lecture interesting and he's good at explaining things as well.", '12/15/2017', 2.0, 4, 4.0, 'A', 880998, 93.0)
# (28024623, 4, 'ENGR102B', 'I loved Dr. Pau! He was a bit monotone in class and read off the lecture slides, but he was so helpful. He genuinely cared about his students and did a lot to help them succeed. He responded to his emails very quickly and was easy to find outside of class.', '04/10/2017', 2.0, 4, 4.0, 'A+', 1948437, 97.0)
# (23872464, 4, 'ENGR102B', "He's a pretty great professor. His speech is slightly accented (not sure what language though) and sometimes he doesn't understand your question, but mostly he's alright. He grades very fairly and the homework is straightforward.", '11/21/2014', 1.0, 4, 4.0, 'A+', 1948437, 97.0)
# (20511809, 5, 'CBIO496J', 'It is a seminar class, but it is still ABCDE graded. Attendance is a must. It is a 1 credit class that you can get an A on just by listening to the guest speakers. It is once a week for an hour. Justt show up and pay attention. Also, Dr. Pawar will help you find a research mentor if you ever need one, just talk to her about it. She is really nice.', '07/24/2012', 1.0, 5, 5.0, 'N/A', 1736464, None)
# (35181438, 3, 'ENGL389', "She's an easy grader, and very knowledgable about the industry, but the structure of the class makes no sense and instructions are often unclear or nonexistent. Not a difficult class, but definitely frustrating and confusing in how it is formatted and presented on D2L.", '11/02/2021', 1.0, 3, 3.0, 'Not sure yet', 2131127, None)
# (35083706, 4, 'ENGL389', 'Good teacher, just gives a lot of work and gives no time to actually complete it', '09/22/2021', 4.0, 4, 4.0, 'A-', 2131127, 90.0)
# (31874053, 3, 'ENGL266', "The course was not as expected. We mostly focused on writing thesis statements, so if you get good grades on the essays then you honestly don't need to go to lecture. We hardly talked about the books that we read, you can get away with spark noting without any problem. Grading criteria is very unclear, but if you ask her she will be more specific.", '05/14/2019', 2.0, 3, 3.0, 'A', 2131127, 93.0)
# (30163565, 4, 'ENGL266', 'I enjoyed this class and the discussions we had. She was an easy grader as long as you showed the effort! There were some papers, response papers, and a larger essay. The class was small that discussions were meaningful! I learned a lot about the history of the f YA genre and structures! So glad I took this class!', '05/21/2018', 3.0, 4, 4.0, 'N/A', 2131127, None)
# (30023495, 5, 'ENGL263', "This is one of the greatest online classes I've ever taken and Professor Pearmain is awesome! Every week you have a few discussion posts, the readings are pretty simple (I just read online summaries and skimmed), and you'll learn a lot about children's literature. The textbook is unnecessary, and only buy the children's books if you want to.", '05/08/2018', 2.0, 5, 5.0, 'A+', 2131127, 97.0)
# (18363077, 2, 'OPTI202R', "Even if you get past the language/accent barrier (which is HIGHLY distracting!) she is a poor teacher; she is extremely bad at explaining things and often gives misinformation. If she's teaching 202R still, you better get used to learning the material on your own.", '04/05/2011', 3.0, 2, 2.0, 'N/A', 1558155, None)
# (34758136, 3, 'PA410', "Peng is a nice guy who is very knowledgeable. However, this was the hardest class I've taken because of the material. Peng helped us out by uploading notes for us every week. The quizzes are all written, not multiple choice. Some of the homework assignments I felt were tough because we didn't go over how exactly to do the math. Tough class!!", '05/10/2021', 5.0, 3, 3.0, 'N/A', 900338, None)
# (33216679, 5, 'PA508', 'Jun is great if you take the time to know him. Hes a fantastic person and really does care about the students and what he teaches. I had no interest in public finance, but this class made me really interested in how the inner govt works the budgeting system. Midterm(22%) /Final(23%), Accounting Assignment(25%), Final Project(30%) how he grades.', '05/06/2020', 4.0, 5, 5.0, 'A', 900338, 93.0)
# (29238426, 3, 'PA410', "Overall this wasn't a terribly hard class but definitely required some effort. He doesn't post any lecture slides whatsoever so you have to attend class regularly, and he also takes random attendance. The midterm and final are almost identical to the study guides.", '12/16/2017', 4.0, 3, 3.0, 'B', 900338, 83.0)
# (21753898, 4, 'PA508', "I call Professor Peng an educator of educators. He has passion for what he does, and he does it very well. I recommend his class for everyone who is interested in budgeting. He knows it very well. Additionally, Professor Peng is culturally sensitive. I'm a foreign student, with a very tick accent, but the professor was patient with me.", '05/14/2013', 1.0, 5, 4.5, 'N/A', 900338, None)
# (18541929, 2, 'PA410', 'Prof. Peng is everything you want in a good teacher. He hands out study guides that are identical to the actual test, he helps his students if they have questions, and the information he teaches pertains to the budgeting crisis today. He also teaches you how to file a personal income tax sheet. Easily one of the most useful Professors at U of A', '05/06/2011', 2.0, 5, 3.5, 'N/A', 900338, None)
# (12285149, 4, 'PA410', 'He is from China, so he has a very strong accent, but he is always willing to help if you are having trouble in his class. His tests are straight from the study guides, and his notes are very structured, which helps since he is hard to understand at first.  He has very few assignments, and they are graded very easily, as long as you try.', '10/14/2006', 4.0, 5, 4.5, 'N/A', 900338, None)
# (33970324, 5, 'GEOS218', "Dr. Pepper gave great, informative lectures. This class consisted of a weekly quiz, weekly discussion post, taking notes/answering questions that you submit each week, and a final. There are extra credit opportunities if you want them. Not a hard class IF you actually do the work. I only consulted the optional textbook once. You don't need it.", '12/07/2020', 3.0, 5, 5.0, 'A', 2263969, 93.0)
# (33600028, 5, 'GEOS251', 'By far one of the best classes I have taken! Mr. Pepper is very helpful and understanding. His lectures are very interesting and he gets back to you immediately if you have any questions or concerns about the material. I 10/10 recommend this class! It would be hard for you to not get a good grade because his material is fun and easy to understand.', '08/20/2020', 2.0, 5, 5.0, 'Not sure yet', 2263969, None)
# (30857921, 4, 'GEOS170', 'Dr. Pepper is great! The class is pretty easy as long as you show up and do the work. Attendance is mandatory and makes up 25% of your grade.', '12/04/2018', 2.0, 4, 4.0, 'A', 2263969, 93.0)
# (32743570, 2, 'AME230', "Worst course I've ever taken. If you end up taking his course don't stress the homework to much, his test questions aren't from the book. He will have 3 days to go over old exams before each exam, take detailed notes and pay attention to tricks he throws in to his old exam. take these practice exams at home multiple times and you'll be ok", '12/22/2019', 4.0, 2, 2.0, 'A', 1127140, 93.0)
# (29525976, 3, 'AME331', 'Due to the honestly unacceptable weight distribution of final grades(hw 10%, midterm 35%, final 55%). Myself and many of my peers were scared the entire semester as 90% of our final grade was to be determined in a mere 3 hours. Zohar is a decent lecturer, but can be rude to questions. Dr. Zohar is much nicer though if you stop by his office hours.', '02/01/2018', 4.0, 3, 3.0, 'B', 1127140, 83.0)
# (29138532, 1, 'AME331', 'There are two types of people rating him on here: those who tell the truth - that he is the worst professor at the UofA; and those who are lying to themselves because they did ok on the exams. Bottom line - he is the worst professor at the UofA. He is awful. No teaching material, no asking questions, worthless office hours, unclear point structure.', '12/11/2017', 5.0, 1, 1.0, 'B', 1127140, 83.0)
# (26969273, 1, 'AME331', "When trying his homework I questioned if I was sitting in on the wrong lecture.  What I learned in class was not at all useful to completing homework or exams. One of the worst professors I've had.", '09/12/2016', 4.0, 1, 1.0, 'N/A', 1127140, None)
# (26895237, 1, 'AME230', "Terrible. Lectures over powerpoints that he didn't write so he jumps around. Grades off of homework 15%, midterm 30%, final 50%, attendance 5%. He gives an example exam that's similar to exam. Won't allow you to see final unless you want re-grade. He is the perfect example of why the UofA sucks for teaching, but great for research.", '08/15/2016', 4.0, 1, 1.0, 'N/A', 1127140, None)
# (26710746, 1, 'AME230', 'You are better off trying to teach yourself. The material covered in lecture will not help you on homework or tests. There is 1 test and 1 final, which averaged at 75 and 45 respectively.  There are random pop quizzes, so be careful when skipping lecture (which you will want to do). Despite the poor teaching, the curve in this course is massive.', '06/09/2016', 4.0, 1, 1.0, 'N/A', 1127140, None)
# (26395305, 4, 'AME230', 'His lectures are on the theory of thermo principles and then homework is all math/application problems.  It was helpful to print the notes and then  write what he says in class.  Go to class. Gives random attendance quizzes.  Only 2 tests (midterm/final) so just study the homework problems. Both tests are open note and open book!', '04/27/2016', 3.0, 3, 3.5, 'N/A', 1127140, None)
# (25744111, 1, 'AME331', 'PSA: Avoid this class like the plague. The professor is very unhelpful, patronizing, and the lectures vaguely represent the material on homework and exams. He takes simple concepts and makes them as confusing as possible. I learned more staring at a dumpster fire. Take the alternative fluid dynamics class or regret it.', '12/17/2015', 5.0, 1, 1.0, 'N/A', 1127140, None)
# (24940088, 1, 'AME331', 'I don\'t know if what I learned in his class is actually the way to do fluid mechanics. We had 1 test 1 final. The final wasn\'t cumulative, and when we were going over the review he did problems for us. He told us "you couldn\'t do this review with the book or the power points, the strategies and knowledge are not covered". Your grade is random.', '06/05/2015', 3.0, 1, 1.0, 'B', 1127140, 83.0)
# (24260108, 1, '330', "I really don't have anything nice to say about this guy. However to prepare for the exams you should work on the practice exam he gives the lecture before the exam, change up the problems a little and try solving it. Do this as many times as you can until you feel you understand what you're doing and you should be fine for the exam.", '01/09/2015', 5.0, 1, 1.0, 'B', 1127140, 83.0)
# (14857211, 4, 'ENGL483', "prof zwinger is a fantastic teacher.  classes are never boring.  i don't know what that other rater could be thinking.  class is always fun and really interesting.  you may not read the canon of dwm, but you can get that in all of your other classes!", '10/08/2008', 4.0, 4, 4.0, 'N/A', 530616, None)
# (14439152, 5, 'ENG484', "Dr. Z is fantastic.  She's always interesting, challenging, and funny.  I highly recommend taking her classes because you'll be a better reader when you finish the course.", '05/09/2008', 4.0, 4, 4.5, 'N/A', 530616, None)
# (14372588, 3, 'ENGL486', "Zwinger is fun.  She is always joking with students.  She will always listen to your comments, and provides good discussion.  Sometimes class can be boring, but she won't call you out if you just sit and look at the ground the entire class.  Would highly recommend her.", '04/30/2008', 2.0, 3, 3.0, 'N/A', 530616, None)
# (2990505, 5, 'ENGL458B', 'Zwinger is a fabulous professor, and I would definitely recommend taking her classes.  She leads great discussions and pushes you to write strong critical essays.', '12/12/2004', 3.0, 4, 4.5, 'N/A', 530616, None)

# %%
sql_head("Review")
# Out:
#    reviewid  clarityrating     courseid  ... coursegrade  profid  coursepercent
# 0  35221583            2.0      HUMS376  ...           A  523510           93.0
# 1  35087586            1.0      AFAS306  ...          WD  523510            NaN
# 2  34786511            1.0      AFAS303  ...           C  523510           73.0
# 3  34777281            1.0  AFASENGL303  ...          B-  523510           80.0
# 4  34593307            3.0       GWS312  ...           B  523510           83.0
#
# [5 rows x 11 columns]

# %% [markdown]
# #Example Queries
# Contains example queries based on some of the possible questions I outlined in HW7.

# %%
# average salary by gender
query = "SELECT InferredGender, AVG(FTESalary) AS AVGFTE, AVG(AcutalSalary) AS AVGActual FROM Professor GROUP BY InferredGender"

run_query(query)
# Out:
#   InferredGender       AVGFTE   AVGActual
# 0           male  102911.1816  97477.1517
# 1         female   88994.7819  83164.4977
# 2           None   94076.1326  88954.9724

# %%
# average salary by gender, grouped by department and title where title has at least two genders
depts_titles_2_genders = '''SELECT Department, Title
              FROM Professor 
              GROUP BY Department, Title
              HAVING COUNT(DISTINCT InferredGender) >= 2'''

other_restriction = "Department LIKE '%Math%'"

query = '''SELECT Department, Title, InferredGender, COUNT(InferredGender), AVG(FTESalary) AS AVGFTE, AVG(AcutalSalary) AS AVGActual 
            FROM Professor
            WHERE (Department, Title) IN (''' + depts_titles_2_genders + '''
            ) AND ''' + other_restriction + '''
            GROUP BY Department, Title, InferredGender
            ORDER BY Department, Title, InferredGender'''

run_query(query)
# Out:
#      Department                              Title  ...       AVGFTE    AVGActual
# 0   Mathematics                Associate Professor  ...   86964.2500   69764.2500
# 1   Mathematics                Associate Professor  ...   84312.0000   84312.0000
# 2   Mathematics                Associate Professor  ...   88238.3000   88238.3000
# 3   Mathematics                         Instructor  ...   42000.0000   42000.0000
# 4   Mathematics                         Instructor  ...   43444.4444   43444.4444
# 5   Mathematics                         Instructor  ...   42750.0000   42750.0000
# 6   Mathematics                           Lecturer  ...   48000.0000   48000.0000
# 7   Mathematics                           Lecturer  ...   48750.0000   42562.5000
# 8   Mathematics                           Lecturer  ...   48500.0000   48500.0000
# 9   Mathematics  Postdoctoral Research Associate I  ...   47659.0000   47659.0000
# 10  Mathematics  Postdoctoral Research Associate I  ...   47659.0000   47659.0000
# 11  Mathematics  Postdoctoral Research Associate I  ...   52579.7500   46622.2500
# 12  Mathematics                          Professor  ...  105111.0000  105111.0000
# 13  Mathematics                          Professor  ...  150265.6667  129670.3333
# 14  Mathematics                          Professor  ...  122504.9375  119868.3750
# 15  Mathematics                    Senior Lecturer  ...   52980.0000   52980.0000
# 16  Mathematics                    Senior Lecturer  ...   56111.6667   56111.6667
# 17  Mathematics                    Senior Lecturer  ...   60124.0000   60124.0000
#
# [18 rows x 6 columns]

# %%
# departments with more than 10 professors order by the highest minority ethnicity percent
query = """SELECT Department, NumProfessors, PercentWhite, 
            PercentBlack + PercentAPI + PercentAIAN + Percent2pRace + PercentHispanic + PercentNonWhite AS PercentMinority
            FROM Department
            WHERE NumProfessors > 10
            ORDER BY PercentMinority DESC"""
run_query(query)
# Out:
#                         Department  ...  PercentMinority
# 0               East Asian Studies  ...         0.750000
# 1                          Finance  ...         0.642857
# 2      Systems and Industrial Engr  ...         0.588235
# 3           Spanish and Portuguese  ...         0.588235
# 4      Aerospace & Mechanical Engr  ...         0.586207
# 5                 Africana Studies  ...         0.538462
# 6   Sch Middle E/N African Studies  ...         0.538462
# 7     Electrical and Computer Engr  ...         0.517241
# 8         Materials Science & Engr  ...         0.500000
# 9                      Mathematics  ...         0.474227
# 10   Speech Language & Hearing Sci  ...         0.466667
# 11                   Communication  ...         0.461538
# 12  Chemistry & Biochemistry - Sci  ...         0.459459
# 13                       Economics  ...         0.458333
# 14  James C Wyant Coll Optical Sci  ...         0.454545
# 15             Steward Observatory  ...         0.454545
# 16              French and Italian  ...         0.444444
# 17                Computer Science  ...         0.428571
# 18  Management Information Systems  ...         0.428571
# 19                     Linguistics  ...         0.428571
# 20       Health Promotion Sciences  ...         0.400000
# 21           School of Accountancy  ...         0.400000
# 22     Hydrology & Atmospheric Sci  ...         0.375000
# 23              College of Nursing  ...         0.363636
# 24                      Psychology  ...         0.354839
# 25  Ecology & Evolutionary Biology  ...         0.352941
# 26  Molecular and Cellular Biology  ...         0.350000
# 27                         Physics  ...         0.347826
# 28                         English  ...         0.340909
# 29  Teachg Learning Sociocult Stds  ...         0.333333
# 30                 School of Music  ...         0.320000
# 31                       Marketing  ...         0.312500
# 32  Animal&Biomedical Sciences-Res  ...         0.307692
# 33              The Honors College  ...         0.307692
# 34                         History  ...         0.307692
# 35  Religious Studies and Classics  ...         0.294118
# 36  Sch of Family & Consum Sci-Ins  ...         0.291667
# 37  School of Govt & Public Policy  ...         0.285714
# 38                 Law Instruction  ...         0.277778
# 39          School of Anthropology  ...         0.275862
# 40   Chemical & Environmental Engr  ...         0.250000
# 41        Nutritional Sciences-Ins  ...         0.250000
# 42           School of Information  ...         0.240000
# 43  Sch of Geography & Development  ...         0.227273
# 44  Sch of Nat Resource&Enviro-Res  ...         0.214286
# 45                       Astronomy  ...         0.210526
# 46   Sch Theatre Film & Television  ...         0.208333
# 47    Management and Organizations  ...         0.208333
# 48                   School of Art  ...         0.200000
# 49                      Journalism  ...         0.200000
# 50                     Geosciences  ...         0.200000
# 51          School of Architecture  ...         0.166667
# 52                       Sociology  ...         0.166667
# 53                      Physiology  ...         0.150000
# 54  Lunar and Planetary Laboratory  ...         0.133333
# 55    School of Plant Sciences-Res  ...         0.125000
# 56                      Philosophy  ...         0.105263
# 57   Disability Psychoeduc Studies  ...         0.043478
#
# [58 rows x 4 columns]

# %%
# most to least difficult courses with more than 10 ratings
other_restriction = "Department LIKE '%Information%'"
query = """SELECT * FROM 
          Course
          WHERE NumRatings > 10 AND """ + other_restriction + """
          ORDER BY AvgEasy ASC"""
run_query(query)
# Out:
#   courseid   avgeasy  ...   profid                      department
# 0  ESOC150  2.153846  ...  1891506           School of Information
# 1   MIS304  2.800000  ...  1705443  Management Information Systems
# 2   MIS373  2.842105  ...  1786909  Management Information Systems
# 3   MIS111  2.918919  ...   880998  Management Information Systems
# 4   MIS441  3.000000  ...   996649  Management Information Systems
# 5  ISTA130  3.250000  ...   980523           School of Information
# 6  ISTA116  3.476191  ...  2284722           School of Information
# 7   MIS531  4.142857  ...  1667601  Management Information Systems
#
# [8 rows x 10 columns]

# %%
# view all the ratings for professor named Jonathan Misurda
query = """SELECT Comment, OverallRating, CourseID, ReviewDate FROM 
          Review JOIN Professor ON (Review.ProfID=Professor.ProfID)
          WHERE FirstName='Jonathan' AND LastName = 'Misurda'"""

pd.set_option('display.max_colwidth', None)
run_query(query)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                      comment  ...  reviewdate
# 0                        Boring speaker, monotone, with no passion. I have Aspergers and have difficulty with social situations. He did not accommodate my disability, just scoffed. Group projects would have been much better if there was a discussion board, forum, or chatsomething to get to know classmates and discuss problems. If I could ask for a refund I would  ...  2021-04-11
# 1              Not understanding the negativity in other reviews. Dude's really enthusiastic about his field and knows what he's teaching backwards and forwards. Classes are very lecture-heavy, but I found that alright because he's a very good speaker. Take good notes and get a good mental model of the material, because it's hard to fake it on his tests/projects  ...  2021-03-17
# 2                            I was really disappointed after taking this class. Dr. Misruda makes this class unnecessarily difficult for no reason. There's absolutely no rubric for assignments. He talks the whole lecture time without any participation, so it's really hard to pay attention. He will cover a needed topic one or two days before an assignment is due.  ...  2021-02-15
# 3                           Dr. Mirsurda is really passionate about the material, but I don't think he relates it to the students. He doesn't give a lot of homework so I you don't do well there isn't much of a buffer. He often speaks the whole lecture, so it's hard to follow for 75 minutes. He often gives snarky responses to the students when they ask questions.  ...  2021-02-15
# 4                     Took two classes (335 and 352) with him and I respect him quite a bit. He got a PhD in JUnit testing, what a mad lad. He's very knowledgeable about programming and is capable of engaging in good discussions about the material. Sometimes, it seems like he's condescending, yeah, but I feel like that's because he thinks this is easier material  ...  2020-11-22
# 5                    I avoid Misurda at every chance I get, you will not find me willingly taking his class. All his lectures are monotoned, without use of examples or direction. Projects are extremely hard, no structure to the course and lack of examples in class. TA's are more helpful at explaining concepts then the teacher. No piazza even tho class is online.  ...  2020-11-20
